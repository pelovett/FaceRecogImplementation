# %%
import tensorflow as tf
import numpy as np
import facial_recog as fr
fr.main()
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\jonah\\Desktop\\Peter471\\PeterFace01\\yale_conv_model', '_tf_random_seed': 1, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_save_checkpoints_steps': None, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000}
# Tensor("fifo_queue_DequeueUpTo:1", shape=(?, 28224), dtype=float32)
# Tensor("conv2d/Relu:0", shape=(?, 168, 168, 350), dtype=float32)
# Tensor("max_pooling2d/MaxPool:0", shape=(?, 42, 42, 350), dtype=float32)
# Tensor("batch_normalization/batchnorm/add_1:0", shape=(?, 42, 42, 350), dtype=float32)
# Tensor("conv2d_2/Relu:0", shape=(?, 42, 42, 60), dtype=float32)
# Tensor("batch_normalization_2/batchnorm/add_1:0", shape=(?, 42, 42, 60), dtype=float32)
# Tensor("max_pooling2d_2/MaxPool:0", shape=(?, 14, 14, 60), dtype=float32)
# Tensor("Reshape_1:0", shape=(?, 11760), dtype=float32)
# ...

# %%
import evaluation as ev
#ev.main()
